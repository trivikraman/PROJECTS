# %% [markdown]
# PART-1 POPULATING AND GATHERING DATA

# %%
# !pip install sqlalchemy

# %%
# !pip install PyMySQL

# %%
import sqlalchemy
import pymysql
import pandas as pd

# %%
pymysql.install_as_MySQLdb()

# %%
indices=['nifty50','rtsi','bovespa']

# %%
def schemacreator(index):
    engine=sqlalchemy.create_engine("mysql://root:msdhoni7@localhost:3306/")
    engine.execute(sqlalchemy.schema.CreateSchema(index))

# %%
for index in indices:
    schemacreator(index)

# %%
nifty=pd.read_html('https://en.wikipedia.org/wiki/NIFTY_50')[1]
bovespa=pd.read_html('https://en.wikipedia.org/wiki/List_of_companies_listed_on_B3')[0]
rts=pd.read_html('https://en.wikipedia.org/wiki/RTS_Index')[1]

# %%
nifty=nifty.Symbol.to_list()

# %%
nifty
# Out:
# ['ADANIPORTS',
#  'APOLLOHOSP',
#  'ASIANPAINT',
#  'AXISBANK',
#  'BAJAJ-AUTO',
#  'BAJFINANCE',
#  'BAJAJFINSV',
#  'BHARTIARTL',
#  'BPCL',
#  'BRITANNIA',
#  'CIPLA',
#  'COALINDIA',
#  'DIVISLAB',
#  'DRREDDY',
#  'EICHERMOT',
#  'GRASIM',
#  'HCLTECH',
#  'HDFC',
#  'HDFCBANK',
#  'HDFCLIFE',
#  'HEROMOTOCO',
#  'HINDALCO',
#  'HINDUNILVR',
#  'ICICIBANK',
#  'INDUSINDBK',
#  'INFY',
#  'ITC',
#  'JSWSTEEL',
#  'KOTAKBANK',
#  'LT',
#  'M&M',
#  'MARUTI',
#  'NESTLEIND',
#  'NTPC',
#  'ONGC',
#  'POWERGRID',
#  'RELIANCE',
#  'SBIN',
#  'SBILIFE',
#  'SHREECEM',
#  'SUNPHARMA',
#  'TATAMOTORS',
#  'TATASTEEL',
#  'TCS',
#  'TATACONSUM',
#  'TECHM',
#  'TITAN',
#  'ULTRACEMCO',
#  'UPL',
#  'WIPRO']

# %%
bovespa=bovespa['Ticker'].to_list()

# %%
rts=rts["Ticker symbol"].to_list()

# %%
#NS-NATIONAL STOCK EXCHANGE-NIFTY,#SA-BOVESPA,#ME-RTS
nifty=[i+".NS" for i in nifty]
bovespa=[i+".SA" for i in bovespa]
rts=[i+'.ME' for i in rts]

# %%
bovespa
# Out:
# ['ALPA4.SA',
#  'ABEV3.SA',
#  'AMER3.SA',
#  'AZUL4.SA',
#  'B3SA3.SA',
#  'BBAS3.SA',
#  'BBSE3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'BIDI11.SA',
#  'BPAN4.SA',
#  'BRAP4.SA',
#  'BRML3.SA',
#  'BRKM5.SA',
#  'BRFS3.SA',
#  'BPAC11.SA',
#  'CRFB3.SA',
#  'CCRO3.SA',
#  'CVCB3.SA',
#  'CMIG4.SA',
#  'CIEL3.SA',
#  'COGN3.SA',
#  'CPLE6.SA',
#  'CSAN3.SA',
#  'CPFE3.SA',
#  'CSNA3.SA',
#  'CYRE3.SA',
#  'DXCO3.SA',
#  'ECOR3.SA',
#  'ENBR3.SA',
#  'ELET3.SA',
#  'ELET6.SA',
#  'EMBR3.SA',
#  'ENGI11.SA',
#  'ENEV3.SA',
#  'EGIE3.SA',
#  'EQTL3.SA',
#  'EZTC3.SA',
#  'GGBR4.SA',
#  'GOLL4.SA',
#  'PCAR3.SA',
#  'SOMA3.SA',
#  'FLRY3.SA',
#  'HAPV3.SA',
#  'HYPE3.SA',
#  'IGTI11.SA',
#  'IRBR3.SA',
#  'ITUB4.SA',
#  'ITSA4.SA',
#  'JBSS3.SA',
#  'JHSF3.SA',
#  'KLBN11.SA',
#  'RENT3.SA',
#  'LWSA3.SA',
#  'LREN3.SA',
#  'MGLU3.SA',
#  'MRFG3.SA',
#  'CASH3.SA',
#  'GOAU4.SA',
#  'BEEF3.SA',
#  'MRVE3.SA',
#  'MULT3.SA',
#  'NTCO3.SA',
#  'PETR3.SA',
#  'PETR4.SA',
#  'VBBR3.SA',
# ...

# %%
# !pip install yfinance
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\users\dell\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import yfinance as yf

# %%
yf.download(nifty[0],start="2022-08-2")
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-08-02  800.849976  810.400024  795.000000  802.299988  802.299988
# 2022-08-03  802.799988  809.900024  795.349976  807.200012  807.200012
# 2022-08-04  811.049988  820.500000  796.500000  807.250000  807.250000
# 2022-08-05  811.099976  818.700012  805.500000  810.250000  810.250000
#
#              Volume
# Date
# 2022-08-02  4393310
# 2022-08-03  3326267
# 2022-08-04  4641779
# 2022-08-05  2806881

# %%
mapper={'nifty50':nifty,'bovespa':bovespa,'rtsi':rts}

# %%
for index in indices:
    engine=sqlalchemy.create_engine("mysql://root:msdhoni7@localhost:3306/"+index)
    for symbol in mapper[index]:
        df=yf.download(symbol,start='2022-01-01')
        df=df.reset_index()
        df.to_sql(symbol,engine)

# %% [markdown]
# PART-2-TECHNICAL INDICATORS

# %%
# !pip install ta
# Out:
# ...
# Using legacy 'setup.py install' for ta, since package 'wheel' is not installed.
# ...
# WARNING: You are using pip version 21.0.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\users\dell\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
#     Running setup.py install for ta: started
#     Running setup.py install for ta: finished with status 'done'
# ...

# %%
import ta
#ta library for technical analysis
import numpy as np

# %%
pymysql.install_as_MySQLdb()#do this always for safety

# %%
engine=sqlalchemy.create_engine("mysql://root:msdhoni7@localhost:3306/"+index)

# %%
def gettables(index):
    query=f"""SELECT table_name FROM information_schema.tables WHERE table_schema='{index}'"""
    df=pd.read_sql(query,engine)
    df['Schema']=index
    return df

# %%
nifty=gettables('nifty50')

# %%
nifty
# Out:
#        TABLE_NAME   Schema
# 0   adaniports.ns  nifty50
# 1   apollohosp.ns  nifty50
# 2   asianpaint.ns  nifty50
# 3     axisbank.ns  nifty50
# 4   bajaj-auto.ns  nifty50
# 5   bajajfinsv.ns  nifty50
# 6   bajfinance.ns  nifty50
# 7   bhartiartl.ns  nifty50
# 8         bpcl.ns  nifty50
# 9    britannia.ns  nifty50
# 10       cipla.ns  nifty50
# 11   coalindia.ns  nifty50
# 12    divislab.ns  nifty50
# 13     drreddy.ns  nifty50
# 14   eichermot.ns  nifty50
# 15      grasim.ns  nifty50
# 16     hcltech.ns  nifty50
# 17        hdfc.ns  nifty50
# 18    hdfcbank.ns  nifty50
# 19    hdfclife.ns  nifty50
# 20  heromotoco.ns  nifty50
# 21    hindalco.ns  nifty50
# 22  hindunilvr.ns  nifty50
# 23   icicibank.ns  nifty50
# 24  indusindbk.ns  nifty50
# 25        infy.ns  nifty50
# 26         itc.ns  nifty50
# 27    jswsteel.ns  nifty50
# 28   kotakbank.ns  nifty50
# 29          lt.ns  nifty50
# 30         m&m.ns  nifty50
# 31      maruti.ns  nifty50
# 32   nestleind.ns  nifty50
# ...

# %%
def getprices(which):
    prices=[]
    for table,schema in zip(which.TABLE_NAME,which.Schema):
        sql=schema+"."+f'`{table}`'#this works in sql
        prices.append(pd.read_sql(f"SELECT Date,Close FROM {sql}",engine))
    return prices

# %%
getprices(nifty)
# Out:
# [          Date       Close
#  0   2022-01-03  736.599976
#  1   2022-01-04  739.250000
#  2   2022-01-05  754.900024
#  3   2022-01-06  739.799988
#  4   2022-01-07  736.099976
#  ..         ...         ...
#  144 2022-08-01  801.250000
#  145 2022-08-02  802.299988
#  146 2022-08-03  807.200012
#  147 2022-08-04  807.250000
#  148 2022-08-05  814.900024
#
#  [149 rows x 2 columns],
#            Date        Close
#  0   2022-01-03  4990.500000
#  1   2022-01-04  4964.600098
#  2   2022-01-05  4973.250000
#  3   2022-01-06  4964.450195
#  4   2022-01-07  5021.850098
#  ..         ...          ...
#  144 2022-08-01  4288.100098
#  145 2022-08-02  4325.899902
#  146 2022-08-03  4310.049805
#  147 2022-08-04  4395.799805
#  148 2022-08-05  4365.750000
#
#  [149 rows x 2 columns],
#            Date        Close
#  0   2022-01-03  3422.399902
#  1   2022-01-04  3459.300049
#  2   2022-01-05  3526.800049
#  3   2022-01-06  3514.649902
#  4   2022-01-07  3576.300049
# ...

# %%
getprices(gettables('nifty50'))
# Out:
# [          Date       Close
#  0   2022-01-03  736.599976
#  1   2022-01-04  739.250000
#  2   2022-01-05  754.900024
#  3   2022-01-06  739.799988
#  4   2022-01-07  736.099976
#  ..         ...         ...
#  144 2022-08-01  801.250000
#  145 2022-08-02  802.299988
#  146 2022-08-03  807.200012
#  147 2022-08-04  807.250000
#  148 2022-08-05  814.900024
#
#  [149 rows x 2 columns],
#            Date        Close
#  0   2022-01-03  4990.500000
#  1   2022-01-04  4964.600098
#  2   2022-01-05  4973.250000
#  3   2022-01-06  4964.450195
#  4   2022-01-07  5021.850098
#  ..         ...          ...
#  144 2022-08-01  4288.100098
#  145 2022-08-02  4325.899902
#  146 2022-08-03  4310.049805
#  147 2022-08-04  4395.799805
#  148 2022-08-05  4365.750000
#
#  [149 rows x 2 columns],
#            Date        Close
#  0   2022-01-03  3422.399902
#  1   2022-01-04  3459.300049
#  2   2022-01-05  3526.800049
#  3   2022-01-06  3514.649902
#  4   2022-01-07  3576.300049
# ...

# %%
def MACDdecision(df):#DIFFERENCE BETWEEN 26 DAY EMA AND 12 DAY EMA-Moving average convergence divergence
    df['MACD_diff']=ta.trend.macd_diff(df.Close)
    df['Decision MACD']=np.where((df.MACD_diff >0)&(df.MACD_diff.shift(1)< 0),True,False)

# %%
def Goldencrossdecision(df):#short term > long term
    df['SMA20']=ta.trend.sma_indicator(df.Close,window=20)
    df['SMA50']=ta.trend.sma_indicator(df.Close,window=50)
    df['Signal']=np.where(df['SMA20']> df['SMA50'],True,False)
    df['Decision GC']=df.Signal.diff()#previous day diff

# %%
def RSI_SMAdecision(df):#oversold <30 overbought >70
    df['RSI']=ta.momentum.rsi(df.Close,window=10)
    df['SMA200']=ta.trend.sma_indicator(df.Close,window=200)
    df['Decision RSI/SMA']=np.where((df.Close >df.SMA200)&(df.RSI <30),True,False)

# %%
def applytechnicals(which):
    prices=getprices(which)
    for frame in prices:
        MACDdecision(frame)
        Goldencrossdecision(frame)
        RSI_SMAdecision(frame)
    return prices

# %%
applytechnicals(nifty)[0]
# Out:
#           Date       Close  MACD_diff  Decision MACD       SMA20       SMA50  \
# 0   2022-01-03  736.599976        NaN          False         NaN         NaN
# 1   2022-01-04  739.250000        NaN          False         NaN         NaN
# 2   2022-01-05  754.900024        NaN          False         NaN         NaN
# 3   2022-01-06  739.799988        NaN          False         NaN         NaN
# 4   2022-01-07  736.099976        NaN          False         NaN         NaN
# ..         ...         ...        ...            ...         ...         ...
# 144 2022-08-01  801.250000   5.593655          False  738.277502  718.169003
# 145 2022-08-02  802.299988   6.380211          False  744.455002  719.172002
# 146 2022-08-03  807.200012   6.727220          False  750.097504  721.158002
# 147 2022-08-04  807.250000   6.455689          False  755.280005  723.273002
# 148 2022-08-05  814.900024   6.281006          False  760.240005  725.509003
#
# ...

# %%
def recommender(which):
    indicators=['Decision MACD','Decision GC','Decision RSI/SMA']
    for symbol,frame in zip(which.TABLE_NAME,applytechnicals(which)):
        if frame.empty is False:
            for indicator in indicators:
                if frame[indicator].iloc[-1]==True:
                    print(f"{indicator} Buying Signal for"+ symbol)

# %%
recommender(gettables('bovespa'))
# Out:
# Decision GC Buying Signal forbbas3.sa
# Decision GC Buying Signal foreqtl3.sa
# Decision MACD Buying Signal formult3.sa
# Decision GC Buying Signal forsbsp3.sa

# %%
#OOPS
class Recommender:
    engine=sqlalchemy.create_engine("mysql://root:msdhoni7@localhost:3306/"+index)

    def __init__(self,index):
        self.index=index
    
    def gettables(self):
        query=f"""SELECT table_name FROM information_schema.tables WHERE table_schema='{self.index}'"""
        df=pd.read_sql(query,self.engine)
        df['Schema']=self.index
        return df

    def getprices(self):
        prices=[]
        for table,schema in zip(self.gettables().TABLE_NAME,self.gettables().Schema):
            sql=schema+"."+f'`{table}`'#this works in sql
            prices.append(pd.read_sql(f"SELECT Date,Close FROM {sql}",self.engine))
        return prices
    
    def maxdate(self):
        sql=self.index+"."+f'`{self.gettables().TABLE_NAME[0]}`'
        return pd.read_sql(f"SELECT MAX(Date) FROM {sql}",self.engine)
    
    def MACDdecision(self,df):#DIFFERENCE BETWEEN 26 DAY EMA AND 12 DAY EMA-Moving average convergence divergence
        df['MACD_diff']=ta.trend.macd_diff(df.Close)
        df['Decision MACD']=np.where((df.MACD_diff >0)&(df.MACD_diff.shift(1)< 0),True,False)

    def Goldencrossdecision(self,df):#short term > long term
        df['SMA20']=ta.trend.sma_indicator(df.Close,window=20)
        df['SMA50']=ta.trend.sma_indicator(df.Close,window=50)
        df['Signal']=np.where(df['SMA20']> df['SMA50'],True,False)
        df['Decision GC']=df.Signal.diff()#previous day diff

    def RSI_SMAdecision(self,df):#oversold <30 overbought >70
        df['RSI']=ta.momentum.rsi(df.Close,window=10)
        df['SMA200']=ta.trend.sma_indicator(df.Close,window=200)
        df['Decision RSI/SMA']=np.where((df.Close >df.SMA200)&(df.RSI <30),True,False)

    def applytechnicals(self):
        prices=self.getprices()
        for frame in prices:
            self.MACDdecision(frame)
            self.Goldencrossdecision(frame)
            self.RSI_SMAdecision(frame)
        return prices

    def recommender(self):
        signals=[]
        indicators=['Decision MACD','Decision GC','Decision RSI/SMA']
        for symbol,frame in zip(self.gettables().TABLE_NAME,self.applytechnicals()):
            if frame.empty is False:
                for indicator in indicators:
                    if frame[indicator].iloc[-1]==True:
                        signals.append(f"{indicator} Buying Signal for"+ symbol)
        return signals

# %%
instnifty=Recommender("nifty50")

# %%
instbovespa=Recommender('bovespa')
instrtsi=Recommender("rtsi")

# %%
from email.message import EmailMessage
import ssl #adds a layer of security
import smtplib
email_sender=""
email_password=""
email_receiver=""

subject='Check out my stock recommendations'
message=f"""\
    Stock Recommendations \
    
    NIFTY
    {instnifty.recommender()}

    BOVESPA
    {instbovespa.recommender()}

    RTSI
    {instrtsi.recommender()}

    ALL THE BEST!!!!

"""
em=EmailMessage()
em['From']=email_sender
em['To']=email_receiver
em['Subject']=subject
em.set_content(message)

context=ssl.create_default_context()

with smtplib.SMTP_SSL('smtp.gmail.com',465,context=context) as smtp:
    smtp.login(email_sender,email_password)
    smtp.sendmail(email_sender,email_receiver,em.as_string())

# %% [markdown]
# MISCELLANEOUS

# %% [markdown]
# GOOGLE TRENDS

# %%
# !pip install pytrends

# %%
nifty=pd.read_html('https://en.wikipedia.org/wiki/NIFTY_50')[1]
nifty=nifty.Symbol.to_list()
nifty=[i.lower() for i in nifty]

# %%
from pytrends.request import TrendReq
pytrends = TrendReq(hl='en-US')  
pytrends.build_payload(nifty[1:5],timeframe='2022-1-1 2022-8-5')

# %%
data = pytrends.interest_over_time()
data = data.drop('isPartial', axis=1)
data
# Out:
#             apollohosp  asianpaint  axisbank  bajaj-auto
# date
# 2022-01-01           0           1        63           0
# 2022-01-02           0           0        46           1
# 2022-01-03           3           5        72           1
# 2022-01-04           0           4        64           0
# 2022-01-05           0           2        74           0
# ...                ...         ...       ...         ...
# 2022-07-29           3           5        58           0
# 2022-07-30           0           4        54           0
# 2022-07-31           0           1        39           0
# 2022-08-01           3           3        47           1
# 2022-08-02           0           3        37           0
#
# [214 rows x 4 columns]
